# %% [markdown]
# # Text mining: Finding hidden information in CRM data
#
# ## Supporting Project for Text Mining Presentation
#
# Author: Jon Sedar
# Date: Spring 2014
#
# ### Data notes
#
# Obviously the client data is confidential, so I've created a dummy dataset based on a list of enforced NAMA properties which has similar features to the client dataset.
#
# Available as a Google Doc here:
# https://docs.google.com/spreadsheet/ccc?key=0AjOXYk-Wh9M2dGt1TWxjZzc5dDBtY29NMjRvUDhUTXc

# %%
# -- coding: utf-8 --
#    @filename: text_mining_presentation_support.py
#    @author: jon.sedar@applied.ai
#    @copyright: Applied AI Ltd UK 2014
#    @license: BSD-3

## Libraries and global options
# %matplotlib inline
#%matplotlib qt
# %qtconsole --colors=linux 
from __future__ import division, print_function
import os
import sys
import re
import string
from time import time

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate

from nltk.tokenize.punkt import PunktWordTokenizer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer

from sklearn.cluster import MiniBatchKMeans
from sklearn.cross_validation import ShuffleSplit
from sklearn.neighbors import RadiusNeighborsClassifier

from IPython.display import Image
import matplotlib.cm as cm
from mpl_toolkits.mplot3d import Axes3D

# pandas formatting
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.width', 1000)
pd.set_option('display.mpl_style', 'default')
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.expand_frame_repr', True)
pd.set_option('display.precision', 5)
pd.set_option('display.max_colwidth', 50)

# handle temporary deprection warning in pandas for describe()
import warnings
warnings.simplefilter("ignore", DeprecationWarning)
warnings.simplefilter("ignore", UserWarning)

# %%
## local custom functions
def rstr(df):
    """Return an imitation of R's str() and summary() functions"""
    return pd.concat([df.describe().transpose()
                      ,pd.DataFrame(df.dtypes)
                      ,df.head().transpose()],axis=1)

def removeNonAscii(s): return "".join(i for i in s if ord(i)<128)

rex1 = re.compile(r"nan")
rex2 = re.compile(r"not defined")
rex3 = re.compile(r"[0-9A-Za-z]")
rex4 = re.compile(r"dublin\s[0-9]")
rex5 = re.compile(r"^[0-9 ]+$")

def clean_text(x):
    """Clean up single raw text string"""
    x1 = x.strip()                      # strip left and right
    x2 = ' '.join(x1.split())           # replace all whitespace with single space
    x3 = removeNonAscii(x2)             # remove non-ascii
    x4 = x3.lower()                     # lowercase
    x5 = rex1.sub("",x4)                # regex remove "nan"
    x6 = rex2.sub("",x5)                # regex remove "not defined"
    
    # split and replace space between dublin and number    
    if rex4.search(x6) != None:
        x0 = ""
        for word in x6.split():
            if word == "dublin":
                x0 = x0 + word + "_"
            else:
                x0 = x0 + word + " "
        x6 = x0.strip()
        
    x7 = rex5.sub("",x6)                # regex remove unbound number    

    return(x7)


def clean_tokens(x):
    """Clean loose punctuation from token lists and concat into single spaced string"""    
    idxs = [i for i, item in enumerate(x) if rex3.search(item)]
    conc = " ".join([x[i] for i in idxs])
    return(conc)

# %% [markdown]
# ## Data Import and Cleaning

# %%
## Import raw data and quick look
raw = pd.read_csv('data/dummy_data_nama_july2011.csv')
raw.rename(columns=lambda x: '_'.join(x.lower().split()), inplace=True)  # colnames: remove spaces and lower
raw.rename(columns=lambda x: x.translate(string.maketrans("",""), string.punctuation), inplace=True)  # colnames: remove punct

print(raw.shape)
rstr(raw)
# Out:
# (847, 10)
#                            count unique                                      top freq       0                                                  0                                        1                                           2                                        3                                   4
# address1                     847    700                     South William Street   10  object                                       Dolmen Hotel                             Holborn Hill                             Unit at Creeney                          Whelan's Quarry                          Teergoneen
# address2                     617    356                                  Dromore   21  object                              Kilkenny Road, Carlow                                Belturbet                                   Belturbet                                   Daragh                              Doolin
# address3                     847    207                                     Cork   80  object                                             Carlow                                    Cavan                                       Cavan                                    Clare                               Clare
# country                      847      3                                  Ireland  576  object                                            Ireland                                  Ireland                                     Ireland                                  Ireland                             Ireland
# fulladdress                  847    738  South William Street, Dublin 2, Ireland   10  object  Dolmen Hotel, Kilkenny Road, Carlow, Carlow, I...  Holborn Hill, Belturbet, Cavan, Ireland  Unit at Creeney, Belturbet, Cavan, Ireland  Whelan's Quarry, Daragh, Clare, Ireland  Teergoneen, Doolin, Clare, Ireland
# assetdescription             847     15                              Residential  219  object                                              Hotel              Development - Not Commenced                                  Industrial                                    Other                   Agricultural Land
# additionalassetdescription    44     33                                   Quarry    8  object                                                NaN                                      NaN                                         NaN                                   Quarry                                 NaN
# numberofcompletedunits       564      2                                   Single  282  object                                             Single                                      NaN                                      Single                                   Single                                 NaN
# receiversfirm                847     44                           Grant Thornton   96  object                                               KPMG                 Keenan Corporate Finance                    RSM Farrell Grant Sparks                           Grant Thornton              PricewaterhouseCoopers
# receiversfirmwebaddress      788     49                     www.grantthornton.ie   93  object                                        www.kpmg.ie                         www.keenancf.com                www.rsmfarrellgrantsparks.ie                     www.grantthornton.ie                      www.pwc.com/ie
#
# [10 rows x 10 columns]

# %%
## Select interesting features and concat into new column for ease of use
feats = ['address1','address2','address3','country','fulladdress'
         ,'assetdescription','additionalassetdescription','receiversfirm']
df = raw[feats]
df['concat'] = df.apply(lambda row: ' '.join([str(col) for col in row]),axis=1)

for i in range(0,10):
    print(df.ix[i,'concat'])
# Out:
# Dolmen Hotel Kilkenny Road, Carlow Carlow Ireland Dolmen Hotel, Kilkenny Road, Carlow, Carlow, Ireland Hotel nan KPMG
# Holborn Hill Belturbet Cavan Ireland Holborn Hill, Belturbet, Cavan, Ireland Development - Not Commenced nan Keenan Corporate Finance
# Unit at Creeney Belturbet Cavan Ireland Unit at Creeney, Belturbet, Cavan, Ireland Industrial nan RSM Farrell Grant Sparks
# Whelan's Quarry Daragh Clare Ireland Whelan's Quarry, Daragh, Clare, Ireland Other Quarry Grant Thornton
# Teergoneen Doolin Clare Ireland Teergoneen, Doolin, Clare, Ireland Agricultural Land nan PricewaterhouseCoopers
# Westpoint Business
# Park, Kilrush Road Ennis Clare Ireland Westpoint Business
# Park, Kilrush Road, Ennis, Clare, Ireland Retail nan BDO
# Ballyaghboy, Doora Ennis Clare Ireland Ballyaghboy, Doora, Ennis, Clare, Ireland Agricultural Land nan RSM Farrell Grant Sparks
# Ballyaghboy, Doora Ennis Clare Ireland Ballyaghboy, Doora, Ennis, Clare, Ireland Development - Not Commenced nan RSM Farrell Grant Sparks
# Whelan's Quarry
# Fountain Cross Ennis Clare Ireland Whelan's Quarry
# Fountain Cross, Ennis, Clare, Ireland Other Quarry Grant Thornton
# Garran na Coille,
# Shanaway Road Ennis Clare Ireland Garran na Coille,
# Shanaway Road, Ennis, Clare, Ireland Residential nan Deloitte & Touche

# %%
## Clean and Tokenise preserving some punctuation
df['concat_clean'] = df['concat'].apply(clean_text)
df['token'] = df['concat_clean'].apply(PunktWordTokenizer().tokenize)
df['token_clean'] = df['token'].apply(clean_tokens)
for i in range(0,10):
    print(df.ix[i,'token_clean'])
# Out:
# dolmen hotel kilkenny road carlow carlow ireland dolmen hotel kilkenny road carlow carlow ireland hotel kpmg
# holborn hill belturbet cavan ireland holborn hill belturbet cavan ireland development not commenced kee corporate fice
# unit at creeney belturbet cavan ireland unit at creeney belturbet cavan ireland industrial rsm farrell grant sparks
# whelan 's quarry daragh clare ireland whelan 's quarry daragh clare ireland other quarry grant thornton
# teergoneen doolin clare ireland teergoneen doolin clare ireland agricultural land pricewaterhousecoopers
# westpoint business park kilrush road ennis clare ireland westpoint business park kilrush road ennis clare ireland retail bdo
# ballyaghboy doora ennis clare ireland ballyaghboy doora ennis clare ireland agricultural land rsm farrell grant sparks
# ballyaghboy doora ennis clare ireland ballyaghboy doora ennis clare ireland development not commenced rsm farrell grant sparks
# whelan 's quarry fountain cross ennis clare ireland whelan 's quarry fountain cross ennis clare ireland other quarry grant thornton
# garran na coille shanaway road ennis clare ireland garran na coille shanaway road ennis clare ireland residential deloitte touche

# %% [markdown]
# ## Vectorization (TF-IDF)
# Transforming the text into a numeric representation

# %%
## Create TF-IDF Vectors
vectorizer = TfidfVectorizer(max_df=0.95, max_features=20000,ngram_range=(1,2)
                            ,stop_words=None #'english'
                            ,use_idf=True,smooth_idf=True)
X = vectorizer.fit_transform(df["token_clean"])
vectorizer.get_feature_names()
X.shape
# Out:
# (847, 4528)

# %% [markdown]
# ## Dimensionality Reduction (SVD)
# Transforming the sparse matrix into a dense matrix representation
#
# Using Singular Value Decomposition (SVD) a method akin to Prinicipal Components Analysis to map the full space onto a reduced feature space

# %%
## Dimensionality reduction and re-normalization
lsa = TruncatedSVD(n_components=100)
Y = lsa.fit_transform(X)
Z = Normalizer(copy=False).fit_transform(Y)
Z.shape
Z[:10,:10]
# Out:
# array([[ 0.12066792,  0.0529184 ,  0.05048628,  0.05051972,  0.05378864,
#         -0.06826115,  0.02009314,  0.02267102, -0.02086406,  0.00929757],
#        [ 0.18290744,  0.10465485,  0.06801369,  0.08783432,  0.05772103,
#         -0.17955743, -0.17469281, -0.21353832,  0.00234138, -0.28440863],
#        [ 0.27038263, -0.10631365, -0.05640579,  0.05986062,  0.03859843,
#         -0.13646346,  0.03000543,  0.01938345,  0.0875287 ,  0.09574495],
#        [ 0.09589981,  0.00626715,  0.06192965,  0.12615508,  0.06009324,
#         -0.06232693, -0.0622164 , -0.22368115,  0.20434955,  0.18886891],
#        [ 0.13099234,  0.05844775,  0.04458209,  0.11046567,  0.06053786,
#         -0.1120905 , -0.08341397, -0.3440233 ,  0.28771604,  0.27142293],
#        [ 0.14282939,  0.0354739 ,  0.06944681,  0.07909259,  0.07150943,
#         -0.17792403, -0.05774599, -0.23802195,  0.25713774,  0.27279602],
#        [ 0.21456125, -0.03291702, -0.03583065,  0.08129242,  0.06010049,
#         -0.14136625, -0.02328786, -0.3247969 ,  0.29292841,  0.26760416],
#        [ 0.2539225 , -0.0207043 , -0.00338322,  0.09166988,  0.0896728 ,
#         -0.23268613, -0.0931476 , -0.40760248,  0.27569992,  0.17306796],
#        [ 0.09895383,  0.00950079,  0.0643168 ,  0.12874621,  0.07816905,
#         -0.08141311, -0.06889861, -0.27375264,  0.2427865 ,  0.23260754],
#        [ 0.1300824 ,  0.06204776,  0.0577233 ,  0.0934121 ,  0.11044304,
#         -0.16619094, -0.02788357, -0.31306905,  0.26777594,  0.29179919]])

# %% [markdown]
# ## Initial Clustering (K-Means)
# Split up the dataset into more manageable chunks

# %%
## Find good number of clusters to use
inertia = {}

for i in range(1,21):
    km = MiniBatchKMeans(n_clusters=i,init='k-means++',n_init=10,random_state=0
                         ,init_size=1000,batch_size=1000,verbose=False)
    t0 = time()
    km.fit(Z)
    print("testing n= "+str(i)+", done %0.3fs" % (time() - t0))
    inertia[i] = km.inertia_   

#%% Choose best num clusters
min(inertia.iterkeys(), key=(lambda key: inertia[key]))    
        
# fig = plt.figure(1, figsize=(6, 6))
# plt.clf()
plt.scatter(inertia.keys(), inertia.values()
            ,c=[1.0-j for j in inertia.values()],cmap="YlGnBu"
            ,alpha=0.8,marker='o',linewidths=0.3)

f = interpolate.interp1d(inertia.keys(), inertia.values())
xnew = np.arange(min(inertia.keys()),max(inertia.keys()),0.1)
plt.plot(xnew,f(xnew),color="b",linestyle="--")
plt.show
# Out:
# testing n= 1, done 0.206s
# testing n= 2, done 0.315s
# testing n= 3, done 0.214s
# testing n= 4, done 0.182s
# testing n= 5, done 0.186s
# testing n= 6, done 0.209s
# testing n= 7, done 0.243s
# testing n= 8, done 0.226s
# testing n= 9, done 0.233s
# testing n= 10, done 0.266s
# testing n= 11, done 0.279s
# testing n= 12, done 0.266s
# testing n= 13, done 0.307s
# testing n= 14, done 0.290s
# testing n= 15, done 0.317s
# testing n= 16, done 0.302s
# testing n= 17, done 0.334s
# testing n= 18, done 0.336s
# testing n= 19, done 0.429s
# testing n= 20, done 0.441s
# <function matplotlib.pyplot.show>

# %%
## Run using fixed chosen cluster count
clust = 15
km = MiniBatchKMeans(n_clusters=clust,init='k-means++',n_init=10,random_state=0
                         ,init_size=1000,batch_size=1000,verbose=False)
km.fit(Z)

#%% Make quick observations of clusters
A = pd.DataFrame(Z)
A["label1"] = km.labels_
A["label1_color"] = (km.labels_+1)/(max(km.labels_)+1)
A.groupby("label1")[0].count()


## Quick plot
fig = plt.figure(1, figsize=(10, 10))
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
labels = A["label1"]
rndpts = np.sort(np.random.choice(A.shape[0], min(1000,A.shape[0]), replace=False))

ax.scatter(A.iloc[rndpts,0],A.iloc[rndpts,1],A.iloc[rndpts,2]
        ,c=A.iloc[rndpts].label1_color
        ,cmap="jet",alpha=0.8,marker='o',linewidths=0.1)

# plot centroids
cntrs = km.cluster_centers_[:,0:3]
ax.scatter(cntrs[:,0],cntrs[:,1],cntrs[:,2]
        ,c=np.arange(1,clust+1,1)/(clust+1)
        ,cmap="jet",alpha=1,marker='D',s=100, linewidths=1.5)

ax.set_xlabel('SVD 1st')
ax.set_ylabel('SVD 2nd')
ax.set_zlabel('SVD 3rd')
plt.show()

# %% [markdown]
# ## Extract clusters of companies for manual labelling

# %%
df['label'] = km.labels_
df.insert(0, 'human_suggested_id', "")

for i in np.unique(km.labels_):
    df.loc[df.label==i].to_csv('data/human_tagging/df_lbl_'+str(i)+'.csv')

# %%
## Take a look at an example set
df.loc[df.label==0]
# Out:
#     human_suggested_id                                           address1           address2   address3  country                                        fulladdress             assetdescription additionalassetdescription             receiversfirm                                             concat                                       concat_clean                                              token                                        token_clean  label
# 2                                                         Unit at Creeney          Belturbet      Cavan  Ireland         Unit at Creeney, Belturbet, Cavan, Ireland                   Industrial                        NaN  RSM Farrell Grant Sparks  Unit at Creeney Belturbet Cavan Ireland Unit a...  unit at creeney belturbet cavan ireland unit a...  [unit, at, creeney, belturbet, cavan, ireland,...  unit at creeney belturbet cavan ireland unit a...      0
# 129                                        Certain Assets at Mill\nStreet        Ballbriggan     Dublin  Ireland  Certain Assets at Mill\nStreet, Ballbriggan, D...      Development - Commenced                        NaN           kavanaghfennell  Certain Assets at Mill\nStreet Ballbriggan Dub...  certain assets at mill street ballbriggan dubl...  [certain, assets, at, mill, street, ballbrigga...  certain assets at mill street ballbriggan dubl...      0
# 137                                      Certain Assets at\nCastle Street             Dalkey     Dublin  Ireland  Certain Assets at\nCastle Street, Dalkey, Dubl...                  Residential                        NaN   W.K Nowlan & Associates  Certain Assets at\nCastle Street Dalkey Dublin...  certain assets at castle street dalkey dublin ...  [certain, assets, at, castle, street, dalkey, ...  certain assets at castle street dalkey dublin ...      0
# 143                                     Certain Assets at\nGlandore Court          Monkstown     Dublin  Ireland  Certain Assets at\nGlandore Court, Monkstown, ...                  Residential                        NaN   W.K Nowlan & Associates  Certain Assets at\nGlandore Court Monkstown Du...  certain assets at glandore court monkstown dub...  [certain, assets, at, glandore, court, monksto...  certain assets at glandore court monkstown dub...      0
# 180                              Certain Assets at\nHowth Junction\nCourt    Kilbarrack Road  Dublin 13  Ireland  Certain Assets at\nHowth Junction\nCourt, Kilb...                  Residential                        NaN       Ferris & Associates  Certain Assets at\nHowth Junction\nCourt Kilba...  certain assets at howth junction court kilbarr...  [certain, assets, at, howth, junction, court, ...  certain assets at howth junction court kilbarr...      0
# 185                           Certain Residential\nUnits at Loreto\nAbbey        Rathfarnham  Dublin 14  Ireland  Certain Residential\nUnits at Loreto\nAbbey, R...                  Residential                        NaN                       PwC  Certain Residential\nUnits at Loreto\nAbbey Ra...  certain residential units at loreto abbey rath...  [certain, residential, units, at, loreto, abbe...  certain residential units at loreto abbey rath...      0
# 188                                        Certain Assets of\nGrove Court     Blanchardstown  Dublin 15  Ireland  Certain Assets of\nGrove Court, Blanchardstown...                    Mixed Use                        NaN  RSM Farrell Grant Sparks  Certain Assets of\nGrove Court Blanchardstown ...  certain assets of grove court blanchardstown d...  [certain, assets, of, grove, court, blanchards...  certain assets of grove court blanchardstown d...      0
# 197                         Certain Assets at\nNewtown Industrial\nEstate            Coolock  Dublin 17  Ireland  Certain Assets at\nNewtown Industrial\nEstate,...                   Industrial                        NaN       Ferris & Associates  Certain Assets at\nNewtown Industrial\nEstate ...  certain assets at newtown industrial estate co...  [certain, assets, at, newtown, industrial, est...  certain assets at newtown industrial estate co...      0
# 198                     Certain Assets at\nMalahide Road\nIndustrial Park            Coolock  Dublin 17  Ireland  Certain Assets at\nMalahide Road\nIndustrial P...                   Industrial                        NaN       Ferris & Associates  Certain Assets at\nMalahide Road\nIndustrial P...  certain assets at malahide road industrial par...  [certain, assets, at, malahide, road, industri...  certain assets at malahide road industrial par...      0
# 243                                      Certain Assets of\nChatham Court                NaN   Dublin 2  Ireland  Certain Assets of\nChatham Court, Dublin 2, Ir...                  Residential                        NaN  RSM Farrell Grant Sparks  Certain Assets of\nChatham Court nan Dublin 2 ...  certain assets of chatham court dublin_2 irela...  [certain, assets, of, chatham, court, dublin_2...  certain assets of chatham court dublin_2 irela...      0
# 260                              Certain Residential\nUnits at The Island         Chapelizod  Dublin 20  Ireland  Certain Residential\nUnits at The Island, Chap...                  Residential                        NaN                       PwC  Certain Residential\nUnits at The Island Chape...  certain residential units at the island chapel...  [certain, residential, units, at, the, island,...  certain residential units at the island chapel...      0
# 267                                       Certain Assets at\nClontarf Bay      Clontarf Road   Dublin 3  Ireland  Certain Assets at\nClontarf Bay, Clontarf Road...                    Mixed Use                        NaN       Ferris & Associates  Certain Assets at\nClontarf Bay Clontarf Road ...  certain assets at clontarf bay clontarf road d...  [certain, assets, at, clontarf, bay, clontarf,...  certain assets at clontarf bay clontarf road d...      0
# 268                                                       Strandville Ave  North Strand Road   Dublin 3  Ireland  Strandville Ave, North Strand Road, Dublin 3, ...                  Residential                        NaN       Ferris & Associates  Strandville Ave North Strand Road Dublin 3 Ire...  strandville ave north strand road dublin_3 ire...  [strandville, ave, north, strand, road, dublin...  strandville ave north strand road dublin_3 ire...      0
# 269                                                         Hibernian Ave  North Strand Road   Dublin 3  Ireland  Hibernian Ave, North Strand Road, Dublin 3, Ir...                  Residential                        NaN       Ferris & Associates  Hibernian Ave North Strand Road Dublin 3 Irela...  hibernian ave north strand road dublin_3 irela...  [hibernian, ave, north, strand, road, dublin_3...  hibernian ave north strand road dublin_3 irela...      0
# 270                      Certain Assets at\nAldborough Court,\nFive Lamps  North Strand Road   Dublin 3  Ireland  Certain Assets at\nAldborough Court,\nFive Lam...                    Mixed Use                        NaN       Ferris & Associates  Certain Assets at\nAldborough Court,\nFive Lam...  certain assets at aldborough court, five lamps...  [certain, assets, at, aldborough, court, ,, fi...  certain assets at aldborough court five lamps ...      0
# 271                                  Certain Assets at\nNorth Strand Road                NaN   Dublin 3  Ireland  Certain Assets at\nNorth Strand Road, Dublin 3...                  Residential                        NaN       Ferris & Associates  Certain Assets at\nNorth Strand Road nan Dubli...  certain assets at north strand road dublin_3 i...  [certain, assets, at, north, strand, road, dub...  certain assets at north strand road dublin_3 i...      0
# 272                     Certain Assets at\nDunne St/North\nGreat Clare...                NaN   Dublin 3  Ireland  Certain Assets at\nDunne St/North\nGreat Clare...                    Mixed Use                        NaN       Ferris & Associates  Certain Assets at\nDunne St/North\nGreat Clare...  certain assets at dunne st/north great clarenc...  [certain, assets, at, dunne, st/north, great, ...  certain assets at dunne st/north great clarenc...      0
# 308                       Certain Residential\nUnits at Smithfield\nLofts  North King Street   Dublin 7  Ireland  Certain Residential\nUnits at Smithfield\nLoft...                  Residential                        NaN                       PwC  Certain Residential\nUnits at Smithfield\nLoft...  certain residential units at smithfield lofts ...  [certain, residential, units, at, smithfield, ...  certain residential units at smithfield lofts ...      0
# 309                        Certain Commercial\nUnits at Smithfield\nLofts  North King Street   Dublin 7  Ireland  Certain Commercial\nUnits at Smithfield\nLofts...                    Mixed Use                        NaN                       PwC  Certain Commercial\nUnits at Smithfield\nLofts...  certain commercial units at smithfield lofts n...  [certain, commercial, units, at, smithfield, l...  certain commercial units at smithfield lofts n...      0
# 355                                        Certain Assets of\nMerlin Park        Dublin Road     Galway  Ireland  Certain Assets of\nMerlin Park, Dublin Road, G...                    Mixed Use                        NaN  RSM Farrell Grant Sparks  Certain Assets of\nMerlin Park Dublin Road Gal...  certain assets of merlin park dublin road galw...  [certain, assets, of, merlin, park, dublin, ro...  certain assets of merlin park dublin road galw...      0
# 403                          Certain Blocks at\nMaynooth Business\nCampus           Maynooth    Kildare  Ireland  Certain Blocks at\nMaynooth Business\nCampus, ...                    Mixed Use                        NaN            Grant Thornton  Certain Blocks at\nMaynooth Business\nCampus M...  certain blocks at maynooth business campus may...  [certain, blocks, at, maynooth, business, camp...  certain blocks at maynooth business campus may...      0
# 430                                        Certain assets at\nMain Street         Portlaoise      Laois  Ireland  Certain assets at\nMain Street, Portlaoise, La...  Development - Not Commenced                        NaN               McStay Luby  Certain assets at\nMain Street Portlaoise Laoi...  certain assets at main street portlaoise laois...  [certain, assets, at, main, street, portlaoise...  certain assets at main street portlaoise laois...      0
# 431                              Certain assets at Kea\nLew Business Park         Portlaoise      Laois  Ireland  Certain assets at Kea\nLew Business Park, Port...                   Industrial                        NaN               McStay Luby  Certain assets at Kea\nLew Business Park Portl...  certain assets at kea lew business park portla...  [certain, assets, at, kea, lew, business, park...  certain assets at kea lew business park portla...      0
# 432                                        Certain assets at\nMain Street         Portlaoise      Laois  Ireland  Certain assets at\nMain Street, Portlaoise, La...                       Retail                        NaN               McStay Luby  Certain assets at\nMain Street Portlaoise Laoi...  certain assets at main street portlaoise laois...  [certain, assets, at, main, street, portlaoise...  certain assets at main street portlaoise laois...      0
# 438                            Certain Assets at\nRinuccini, Dublin\nRoad         Portlaoise      Laois  Ireland  Certain Assets at\nRinuccini, Dublin\nRoad, Po...      Development - Commenced                        NaN  RSM Farrell Grant Sparks  Certain Assets at\nRinuccini, Dublin\nRoad Por...  certain assets at rinuccini, dublin road portl...  [certain, assets, at, rinuccini, ,, dublin, ro...  certain assets at rinuccini dublin road portla...      0
# 560                                    Certain Assets at\nWestbury Woods,        Enniscorthy    Wexford  Ireland  Certain Assets at\nWestbury Woods,, Enniscorth...                  Residential                        NaN  RSM Farrell Grant Sparks  Certain Assets at\nWestbury Woods, Enniscorthy...  certain assets at westbury woods, enniscorthy ...  [certain, assets, at, westbury, woods, ,, enni...  certain assets at westbury woods enniscorthy w...      0
# 561                                                   Lands at Clonhaston        Enniscorthy    Wexford  Ireland  Lands at Clonhaston, Enniscorthy, Wexford, Ire...            Agricultural Land                        NaN  RSM Farrell Grant Sparks  Lands at Clonhaston Enniscorthy Wexford Irelan...  lands at clonhaston enniscorthy wexford irelan...  [lands, at, clonhaston, enniscorthy, wexford, ...  lands at clonhaston enniscorthy wexford irelan...      0
#
# [27 rows x 14 columns]
