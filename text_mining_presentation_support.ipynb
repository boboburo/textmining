# %% [markdown]
# # Text mining: Finding hidden information in CRM data
#
# ## Supporting Project for Text Mining Presentation
#
# Author: Jon Sedar
# Date: Spring 2014
#
# ### Data notes
#
# Obviously the client data is confidential, so I've created a dummy dataset based on a list of enforced NAMA properties which has similar features to the client dataset.
#
# Available as a Google Doc here:
# https://docs.google.com/spreadsheet/ccc?key=0AjOXYk-Wh9M2dGt1TWxjZzc5dDBtY29NMjRvUDhUTXc

# %%
# -- coding: utf-8 --
#    @filename: text_mining_presentation_support.py
#    @author: jon.sedar@applied.ai
#    @copyright: Applied AI Ltd UK 2014
#    @license: BSD-3

## Libraries and global options
# %matplotlib inline
#%matplotlib qt
# %qtconsole --colors=linux 
from __future__ import division, print_function
import os
import sys
import re
import string
from time import time

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate

from nltk.tokenize.punkt import PunktWordTokenizer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer

from sklearn.cluster import MiniBatchKMeans
from sklearn.cross_validation import ShuffleSplit
from sklearn.neighbors import RadiusNeighborsClassifier

from IPython.display import Image
import matplotlib.cm as cm
from mpl_toolkits.mplot3d import Axes3D

# pandas formatting
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.width', 1000)
pd.set_option('display.mpl_style', 'default')
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.expand_frame_repr', True)
pd.set_option('display.precision', 5)
pd.set_option('display.max_colwidth', 50)

# handle temporary deprection warning in pandas for describe()
import warnings
warnings.simplefilter("ignore", DeprecationWarning)
warnings.simplefilter("ignore", UserWarning)

# %%
## local custom functions
def rstr(df):
    """Return an imitation of R's str() and summary() functions"""
    return pd.concat([df.describe().transpose()
                      ,pd.DataFrame(df.dtypes)
                      ,df.head().transpose()],axis=1)

def removeNonAscii(s): return "".join(i for i in s if ord(i)<128)

rex1 = re.compile(r"nan")
rex2 = re.compile(r"not defined")
rex3 = re.compile(r"[0-9A-Za-z]")
rex4 = re.compile(r"dublin\s[0-9]")
rex5 = re.compile(r"^[0-9 ]+$")

def clean_text(x):
    """Clean up single raw text string"""
    x1 = x.strip()                      # strip left and right
    x2 = ' '.join(x1.split())           # replace all whitespace with single space
    x3 = removeNonAscii(x2)             # remove non-ascii
    x4 = x3.lower()                     # lowercase
    x5 = rex1.sub("",x4)                # regex remove "nan"
    x6 = rex2.sub("",x5)                # regex remove "not defined"
    
    # split and replace space between dublin and number    
    if rex4.search(x6) != None:
        x0 = ""
        for word in x6.split():
            if word == "dublin":
                x0 = x0 + word + "_"
            else:
                x0 = x0 + word + " "
        x6 = x0.strip()
        
    x7 = rex5.sub("",x6)                # regex remove unbound number    

    return(x7)


def clean_tokens(x):
    """Clean loose punctuation from token lists and concat into single spaced string"""    
    idxs = [i for i, item in enumerate(x) if rex3.search(item)]
    conc = " ".join([x[i] for i in idxs])
    return(conc)

# %% [markdown]
# ## Data Import and Cleaning

# %%
## Import raw data and quick look
raw = pd.read_csv('data/dummy_data_nama_july2011.csv')
raw.rename(columns=lambda x: '_'.join(x.lower().split()), inplace=True)  # colnames: remove spaces and lower
raw.rename(columns=lambda x: x.translate(string.maketrans("",""), string.punctuation), inplace=True)  # colnames: remove punct

rstr(raw)
# Out:
#                            count unique                                      top freq       0                                                  0                                        1                                           2                                        3                                   4
# address1                     847    700                     South William Street   10  object                                       Dolmen Hotel                             Holborn Hill                             Unit at Creeney                          Whelan's Quarry                          Teergoneen
# address2                     617    356                                  Dromore   21  object                              Kilkenny Road, Carlow                                Belturbet                                   Belturbet                                   Daragh                              Doolin
# address3                     847    207                                     Cork   80  object                                             Carlow                                    Cavan                                       Cavan                                    Clare                               Clare
# country                      847      3                                  Ireland  576  object                                            Ireland                                  Ireland                                     Ireland                                  Ireland                             Ireland
# fulladdress                  847    738  South William Street, Dublin 2, Ireland   10  object  Dolmen Hotel, Kilkenny Road, Carlow, Carlow, I...  Holborn Hill, Belturbet, Cavan, Ireland  Unit at Creeney, Belturbet, Cavan, Ireland  Whelan's Quarry, Daragh, Clare, Ireland  Teergoneen, Doolin, Clare, Ireland
# assetdescription             847     15                              Residential  219  object                                              Hotel              Development - Not Commenced                                  Industrial                                    Other                   Agricultural Land
# additionalassetdescription    44     33                                   Quarry    8  object                                                NaN                                      NaN                                         NaN                                   Quarry                                 NaN
# numberofcompletedunits       564      2                                   Single  282  object                                             Single                                      NaN                                      Single                                   Single                                 NaN
# receiversfirm                847     44                           Grant Thornton   96  object                                               KPMG                 Keenan Corporate Finance                    RSM Farrell Grant Sparks                           Grant Thornton              PricewaterhouseCoopers
# receiversfirmwebaddress      788     49                     www.grantthornton.ie   93  object                                        www.kpmg.ie                         www.keenancf.com                www.rsmfarrellgrantsparks.ie                     www.grantthornton.ie                      www.pwc.com/ie
#
# [10 rows x 10 columns]

# %%
## Select interesting features and concat into new column for ease of use
feats = ['address1','address2','address3','country','fulladdress'
         ,'assetdescription','additionalassetdescription','receiversfirm']
df = raw[feats]
df['concat'] = df.apply(lambda row: ' '.join([str(col) for col in row]),axis=1)

for i in range(0,10):
    print(df.ix[i,'concat'])
# Out:
# Dolmen Hotel Kilkenny Road, Carlow Carlow Ireland Dolmen Hotel, Kilkenny Road, Carlow, Carlow, Ireland Hotel nan KPMG
# Holborn Hill Belturbet Cavan Ireland Holborn Hill, Belturbet, Cavan, Ireland Development - Not Commenced nan Keenan Corporate Finance
# Unit at Creeney Belturbet Cavan Ireland Unit at Creeney, Belturbet, Cavan, Ireland Industrial nan RSM Farrell Grant Sparks
# Whelan's Quarry Daragh Clare Ireland Whelan's Quarry, Daragh, Clare, Ireland Other Quarry Grant Thornton
# Teergoneen Doolin Clare Ireland Teergoneen, Doolin, Clare, Ireland Agricultural Land nan PricewaterhouseCoopers
# Westpoint Business
# Park, Kilrush Road Ennis Clare Ireland Westpoint Business
# Park, Kilrush Road, Ennis, Clare, Ireland Retail nan BDO
# Ballyaghboy, Doora Ennis Clare Ireland Ballyaghboy, Doora, Ennis, Clare, Ireland Agricultural Land nan RSM Farrell Grant Sparks
# Ballyaghboy, Doora Ennis Clare Ireland Ballyaghboy, Doora, Ennis, Clare, Ireland Development - Not Commenced nan RSM Farrell Grant Sparks
# Whelan's Quarry
# Fountain Cross Ennis Clare Ireland Whelan's Quarry
# Fountain Cross, Ennis, Clare, Ireland Other Quarry Grant Thornton
# Garran na Coille,
# Shanaway Road Ennis Clare Ireland Garran na Coille,
# Shanaway Road, Ennis, Clare, Ireland Residential nan Deloitte & Touche

# %%
## Clean and Tokenise preserving some punctuation
df['concat_clean'] = df['concat'].apply(clean_text)
df['token'] = df['concat_clean'].apply(PunktWordTokenizer().tokenize)
df['token_clean'] = df['token'].apply(clean_tokens)
for i in range(0,10):
    print(df.ix[i,'token_clean'])
# Out:
# dolmen hotel kilkenny road carlow carlow ireland dolmen hotel kilkenny road carlow carlow ireland hotel kpmg
# holborn hill belturbet cavan ireland holborn hill belturbet cavan ireland development not commenced kee corporate fice
# unit at creeney belturbet cavan ireland unit at creeney belturbet cavan ireland industrial rsm farrell grant sparks
# whelan 's quarry daragh clare ireland whelan 's quarry daragh clare ireland other quarry grant thornton
# teergoneen doolin clare ireland teergoneen doolin clare ireland agricultural land pricewaterhousecoopers
# westpoint business park kilrush road ennis clare ireland westpoint business park kilrush road ennis clare ireland retail bdo
# ballyaghboy doora ennis clare ireland ballyaghboy doora ennis clare ireland agricultural land rsm farrell grant sparks
# ballyaghboy doora ennis clare ireland ballyaghboy doora ennis clare ireland development not commenced rsm farrell grant sparks
# whelan 's quarry fountain cross ennis clare ireland whelan 's quarry fountain cross ennis clare ireland other quarry grant thornton
# garran na coille shanaway road ennis clare ireland garran na coille shanaway road ennis clare ireland residential deloitte touche

# %% [markdown]
# ## Vectorization (TF-IDF)
# Transforming the text into a numeric representation

# %%
## Create TF-IDF Vectors
vectorizer = TfidfVectorizer(max_df=0.95, max_features=20000,ngram_range=(1,2)
                            ,stop_words=None #'english'
                            ,use_idf=True,smooth_idf=True)
X = vectorizer.fit_transform(df["token_clean"])
vectorizer.get_feature_names()
# Out:
# [u'0at',
#  u'0at great',
#  u'0ht',
#  u'0ht great',
#  u'0nt',
#  u'0nt great',
#  u'0nw',
#  u'0nw great',
#  u'0rw',
#  u'0rw great',
#  u'1bb',
#  u'1bb great',
#  u'1bh',
#  u'1bh great',
#  u'1bx',
#  u'1bx great',
#  u'1db',
#  u'1db great',
#  u'1dh',
#  u'1dh great',
#  u'1dy',
#  u'1dy great',
#  u'1en',
#  u'1en great',
#  u'1gj',
#  u'1gj great',
#  u'1gl',
#  u'1gl great',
#  u'1pf',
#  u'1pf great',
#  u'1pz',
#  u'1pz great',
#  u'1qp',
#  u'1qp great',
#  u'1qq',
#  u'1qq great',
#  u'1tp',
#  u'1tp great',
#  u'20',
#  u'20 20',
#  u'20 house',
#  u'2ae',
#  u'2ae great',
#  u'2ds',
#  u'2ds great',
#  u'2el',
#  u'2el great',
#  u'2jb',
#  u'2jb great',
#  u'2nd',
#  u'2nd great',
#  u'2py',
#  u'2py great',
#  u'3dr',
#  u'3dr great',
#  u'3ee',
#  u'3ee great',
#  u'3ep',
#  u'3ep great',
#  u'3gt',
#  u'3gt northern',
#  u'3ry',
#  u'3ry great',
#  u'3uz',
#  u'3uz great',
#  u'4ad',
#  u'4ad great',
#  u'4az',
#  u'4az great',
#  u'4be',
#  u'4be great',
#  u'4dg',
#  u'4dg great',
#  u'4ey',
#  u'4ey great',
#  u'4ht',
#  u'4ht great',
#  u'4jb',
#  u'4jb great',
#  u'4lh',
#  u'4lh great',
#  u'4lu',
#  u'4lu great',
#  u'4pp',
#  u'4pp northern',
#  u'4rl',
#  u'4rl great',
#  u'4rt',
#  u'4rt great',
#  u'50',
#  u'50 student',
#  u'5ad',
#  u'5ad great',
#  u'5ap',
#  u'5ap great',
#  u'5as',
#  u'5as northern',
#  u'5eb',
#  u'5eb great',
#  u'5jj',
#  u'5jj great',
#  u'5lb',
#  u'5lb great',
#  u'5qu',
#  u'5qu great',
#  u'5sy',
#  u'5sy great',
#  u'5tz',
#  u'5tz great',
#  u'5xt',
#  u'5xt great',
#  u'6ae',
#  u'6ae great',
#  u'6ha',
#  u'6ha great',
#  u'6jq',
#  u'6jq great',
#  u'6ls',
#  u'6ls great',
#  u'6lu',
#  u'6lu great',
#  u'6ly',
#  u'6ly great',
#  u'6nd',
#  u'6nd great',
#  u'6tj',
#  u'6tj great',
#  u'7ab',
#  u'7ab great',
#  u'7ae',
#  u'7ae great',
#  u'7ay',
#  u'7ay great',
#  u'7lj',
#  u'7lj great',
#  u'7ll',
#  u'7ll great',
#  u'7nb',
#  u'7nb great',
#  u'7nh',
#  u'7nh northern',
#  u'7nl',
#  u'7nl great',
#  u'7sh',
#  u'7sh northern',
#  u'7uj',
#  u'7uj great',
#  u'8an',
#  u'8an great',
#  u'8hs',
#  u'8hs great',
#  u'8hw',
#  u'8hw great',
#  u'8jh',
#  u'8jh great',
#  u'8rn',
#  u'8rn great',
#  u'9bn',
#  u'9bn great',
#  u'9bz',
#  u'9bz great',
#  u'9ea',
#  u'9ea great',
#  u'9ha',
#  u'9ha great',
#  u'abbey',
#  u'abbey building',
#  u'abbey dublin_7',
#  u'abbey rathfarnham',
#  u'abbey road',
#  u'abbey street',
#  u'abbeydorney',
#  u'abbeydorney kerry',
#  u'abbots',
#  u'abbots way',
#  u'abenbury',
#  u'abenbury road',
#  u'abhainn',
#  u'abhainn na',
#  u'accomb',
#  u'accomb york',
#  u'accommodation',
#  u'accommodation national',
#  u'adare',
#  u'adare limerick',
#  u'adelaide',
#  u'adelaide chambers',
#  u'adelaide square',
#  u'agricultural',
#  u'agricultural land',
#  u'aherlow',
#  u'aherlow tipperary',
#  u'ailesbury',
#  u'ailesbury road',
#  u'ailesbury wood',
#  u'airfield',
#  u'airfield dundrum',
#  u'airport',
#  u'airport dublin',
#  u'airport kpmg',
#  u'airport leixlip',
#  u'airside',
#  u'airside business',
#  u'airton',
#  u'airton road',
#  u'aldborough',
#  u'aldborough court',
#  u'aldgate',
#  u'aldgate london',
#  u'alexandra',
#  u'alexandra park',
#  u'alexandra walk',
#  u'allsop',
#  u'allsop llp',
#  u'ambergate',
#  u'ambergate derbyshire',
#  u'an',
#  u'an choiste',
#  u'an tulan',
#  u'and',
#  u'and ballintyre',
#  u'and car',
#  u'and castleforbes',
#  u'and ellenbank',
#  u'and golf',
#  u'and mayor',
#  u'and north',
#  u'and old',
#  u'and paul',
#  u'and st',
#  u'andover',
#  u'andover great',
#  u'angel',
#  u'angel way',
#  u'ann',
#  u'ann road',
#  u'annaghbane',
#  u'annaghbane road',
#  u'antrim',
#  u'antrim northern',
#  u'apartment',
#  u'apartment at',
#  u'apartment francis',
#  u'apartment on',
#  u'apartments',
#  u'apartments banbridge',
#  u'apartments citywest',
#  u'apartments doughiska',
#  u'apartments leigh',
#  u'arbour',
#  u'arbour hill',
#  u'arcadia',
#  u'arcadia centre',
#  u'arcadia retail',
#  u'ard',
#  u'ard ban',
#  u'ard shionnach',
#  u'ardamadane',
#  u'ardamadane blarney',
#  u'ardee',
#  u'ardee road',
#  u'ardfield',
#  u'ardfield douglas',
#  u'ardfield road',
#  u'ardfin',
#  u'ardfin tipperary',
#  u'ardglass',
#  u'ardglass bt30',
#  u'argyle',
#  u'argyle street',
#  u'armagh',
#  u'armagh northern',
#  u'armagh road',
#  u'arrabawn',
#  u'arrabawn centre',
#  u'arran',
#  u'arran quay',
#  u'arus',
#  u'arus bun',
#  u'ashbourne',
#  u'ashbourne meath',
#  u'ashbourne road',
#  u'ashbourne villas',
#  u'ashford',
#  u'ashford kent',
#  u'ashford lands',
#  u'ashford wicklow',
#  u'ashtown',
#  u'ashtown dublin_15',
#  u'assets',
#  u'assets at',
#  u'assets of',
#  u'associates',
#  u'at',
#  u'at aldborough',
#  u'at barrow',
#  u'at bellevue',
#  u'at botanic',
#  u'at castle',
#  u'at chapel',
#  u'at clonhaston',
#  u'at clontarf',
#  u'at cork',
#  u'at creeney',
#  u'at dunne',
#  u'at forest',
#  u'at glandore',
#  u'at grafton',
#  u'at grand',
#  u'at greengate',
#  u'at howth',
#  u'at kea',
#  u'at kilmainham',
#  u'at loreto',
#  u'at main',
#  u'at malahide',
#  u'at maynooth',
#  u'at mill',
#  u'at millenium',
#  u'at moss',
#  u'at newtown',
#  u'at north',
#  u'at red',
#  u'at rinuccini',
#  u'at ropewalk',
#  u'at sillivan',
#  u'at smithfield',
#  u'at south',
#  u'at st',
#  u'at sugarmill',
#  u'at the',
#  u'at trimgate',
#  u'at westbury',
#  u'atherton',
#  u'atherton m46',
#  u'athlone',
#  u'athlone westmeath',
#  u'athy',
#  u'athy kildare',
#  u'aughnacloy',
#  u'aughnacloy tyrone',
#  u'augustine',
#  u'augustine street',
#  u'ave',
#  u'ave north',
#  u'avenue',
#  u'avenue accomb',
#  u'avenue blackrock',
#  u'avenue caherdavin',
#  u'avenue dublin_9',
#  u'avenue jarrow',
#  u'avenue london',
#  u'avenue newcastle',
#  u'avenue raheen',
#  u'avenue rathgar',
#  u'avenue romford',
#  u'avenue santry',
#  u'axbridge',
#  u'axbridge somerset',
#  u'b5',
#  u'b5 6ha',
#  u'ba5',
#  u'ba5 1tp',
#  u'back',
#  u'back road',
#  u'baker',
#  u'baker tilly',
#  u'bakery',
#  u'bakery lane',
#  u'bakery site',
#  u'balfe',
#  u'balfe street',
#  u'ballbriggan',
#  u'ballbriggan dublin',
#  u'balleycorey',
#  u'balleycorey gort',
#  u'ballina',
#  u'ballina tipperary',
#  u'ballinasloe',
#  u'ballinasloe galway',
#  u'ballinderry',
#  u'ballinderry road',
#  u'ballindinas',
#  u'ballindinas barntown',
#  u'ballinhassig',
#  u'ballinhassig cork',
#  u'ballinteer',
#  u'ballinteer dublin_16',
#  u'ballintyre',
#  u'ballintyre hall',
#  u'ballintyre house',
#  u'ballsbridge',
#  u'ballsbridge dublin_4',
#  u'ballyaghboy',
#  u'ballyaghboy doora',
#  u'ballybofey',
#  u'ballybofey donegal',
#  u'ballybrit',
#  u'ballybrit business',
#  u'ballybrit galway',
#  u'ballybritt',
#  u'ballybritt galway',
#  u'ballybrittas',
#  u'ballybrittas laois',
#  u'ballybunnion',
#  u'ballybunnion clare',
#  u'ballycarahan',
#  u'ballycarahan caherdaniel',
#  u'ballycoolin',
#  u'ballycoolin road',
#  u'ballyferriter',
#  u'ballyferriter kerry',
#  u'ballygologue',
#  u'ballygologue road',
#  u'ballygowan',
#  u'ballygowan road',
#  u'ballyhaskey',
#  u'ballyhaskey newtowncunningham',
#  u'ballyheigue',
#  u'ballyheigue kerry',
#  u'ballylifford',
#  u'ballylifford tyrone',
#  u'ballymabin',
#  u'ballymabin dunmore',
#  u'ballymacool',
#  u'ballymacool letterkenny',
#  u'ballymacross',
#  u'ballymacross granard',
#  u'ballymoe',
#  u'ballymoe galway',
#  u'ballymoneen',
#  u'ballymoneen ennis',
#  u'ballyragget',
#  u'ballyragget kilkenny',
#  u'balreask',
#  u'balreask cross',
#  u'ban',
#  u'ban muff',
#  u'banbridge',
#  u'banbridge bt32',
#  u'banbridge down',
#  u'banbridge road',
#  u'bandon',
#  u'bandon cork',
#  u'bangor',
#  u'bangor down',
#  u'bangor great',
#  u'bangor gwynedd',
#  u'bank',
#  u'bank emmet',
#  u'bank hey',
#  u'bank manchester',
#  u'bank road',
#  u'bank street',
#  u'barban',
#  u'barban hill',
#  u'barleyhouse',
#  u'barleyhouse cork',
#  u'barna',
#  u'barna road',
#  u'barntown',
#  u'barntown wexford',
#  u'barrington',
#  u'barrington street',
#  u'barronstown',
#  u'barronstown road',
#  u'barrow',
#  u'barrow street',
#  u'bay',
#  u'bay carrigart',
#  u'bay clontarf',
#  u'bdo',
#  u'bdo ireland',
#  u'bdo llp',
#  u'bdo northern',
#  u'beach',
#  u'beach cobh',
#  u'beacon',
#  u'beacon south',
#  u'beaufort',
#  u'beaufort kerry',
#  u'bedford',
#  u'bedford great',
#  u'bedford row',
#  u'beech',
#  u'beech hill',
#  u'beech meadows',
#  u'beechfield',
#  u'beechfield mews',
#  u'beechwood',
#  u'beechwood avenue',
#  u'beechwood brookborough',
#  u'beechwood place',
#  u'begbies',
#  u'begbies traynor',
#  u'belfast',
#  u'belfast antrim',
#  u'belfast bt9',
#  u'belfast northern',
#  u'belgard',
#  u'belgard road',
#  u'bellevue',
#  u'bellevue islandbridge',
#  u'bellharbour',
#  u'bellharbour clare',
#  u'belsize',
#  u'belsize meadows',
#  u'belturbet',
#  u'belturbet cavan',
#  u'benbow',
#  u'benbow street',
#  u'benedicts',
#  u'benedicts rc',
#  u'benefer',
#  u'benefer way',
#  u'beragh',
#  u'beragh tyrone',
#  u'berkshire',
#  u'berkshire great',
#  u'binfield',
#  u'binfield isle',
#  u'birkenhead',
#  u'birkenhead ch41',
#  u'birmingham',
#  u'birmingham b5',
#  u'birmingham great',
#  u'bishopric',
#  u'bishopric horsham',
#  u'bishopstown',
#  u'bishopstown cork',
#  u'bl9',
#  u'bl9 7ay',
#  u'black',
#  u'black abbey',
#  u'blackfriars',
#  u'blackfriars road',
#  u'blackhall',
#  u'blackhall street',
#  u'blackley',
#  u'blackley manchester',
#  u'blackpool',
#  u'blackpool great',
#  u'blackrock',
#  u'blackrock dublin',
#  u'blackscull',
#  u'blackscull road',
#  u'blanchardstown',
#  u'blanchardstown dublin_15',
#  u'blarney',
#  u'blarney business',
#  u'blarney cork',
#  u'bletchley',
#  u'bletchley mk1',
#  u'block',
#  u'block north',
#  u'blocks',
#  u'blocks at',
#  u'blue',
#  u'blue cedars',
#  u'bluegrove',
#  u'bluegrove cobh',
#  u'blyth',
#  u'blyth great',
#  u'bn9',
#  u'bn9 9ea',
#  u'boathouse',
#  u'boathouse ernst',
#  u'boggafin',
#  u'boggafin monksland',
#  u'bogganfin',
#  u'bogganfin athlone',
#  u'bohemia',
#  u'bohemia road',
#  u'boheraroan',
#  u'boheraroan newmarket',
#  u'bond',
#  u'bond street',
#  u'booterstown',
#  u'booterstown marsh',
#  u'borough',
#  u'borough road',
#  u'boru',
#  u'boru court',
#  u'botanic',
#  u'botanic road',
#  u'bowden',
#  u'bowden row',
#  u'bower',
#  u'bower timoleague',
#  u'bramley',
#  u'bramley oranmore',
#  u'bray',
#  u'bray wicklow',
#  u'bren',
#  u'bren keane',
#  u'briars',
#  u'briars lane',
#  u'bridge',
#  u'bridge road',
#  u'bridge street',
#  u'britain',
#  u'britain 20',
#  u'britain abenbury',
#  u'britain aldgate',
#  u'britain alexandra',
#  u'britain angel',
#  u'britain arcadia',
#  u'britain argyle',
#  u'britain ashbourne',
#  u'britain bank',
#  u'britain benbow',
#  u'britain bishopric',
#  u'britain blackfriars',
#  u'britain bohemia',
#  u'britain borough',
#  u'britain briars',
#  u'britain bridge',
#  u'britain brook',
#  u'britain brookfield',
#  u'britain burgmuir',
#  u'britain bywater',
#  u'britain car',
#  u'britain caveland',
#  u'britain certain',
#  u'britain chapel',
#  u'britain church',
#  u'britain city',
#  u'britain clapham',
#  u'britain clifton',
#  u'britain cobham',
#  u'britain college',
#  u'britain common',
#  u'britain concorde',
#  u'britain connaught',
#  u'britain cormorant',
#  u'britain cromwell',
#  u'britain denbigh',
#  u'britain development',
#  u'britain dingwall',
#  u'britain dock',
#  u'britain duke',
#  u'britain dukes',
#  u'britain east',
#  u'britain edward',
#  u'britain elms',
#  u'britain factory',
#  u'britain fleet',
#  u'britain fore',
#  u'britain former',
#  u'britain frances',
#  u'britain garthorpe',
#  u'britain glastonbury',
#  u'britain gloucester',
#  u'britain granby',
#  u'britain haling',
#  u'britain hall',
#  u'britain hamilton',
#  u'britain hardwicks',
#  u'britain heron',
#  u'britain high',
#  u'britain horseley',
#  u'britain hotel',
#  u'britain huddersfield',
#  u'britain industrial',
#  u'britain international',
#  u'britain irving',
#  u'britain island',
#  u'britain junction',
#  u'britain kean',
#  u'britain king',
#  u'britain kirby',
#  u'britain land',
#  u'britain leicester',
#  u'britain liberty',
#  u'britain lincoln',
#  u'britain lindsey',
#  u'britain liverpool',
#  u'britain lochinvar',
#  u'britain london',
#  u'britain longbrook',
#  u'britain lower',
#  u'britain main',
#  u'britain manor',
#  u'britain meadow',
#  u'britain mill',
#  u'britain minories',
#  u'britain mixed',
#  u'britain mount',
#  u'britain murray',
#  u'britain new',
#  u'britain office',
#  u'britain old',
#  u'britain orford',
#  u'britain other',
#  u'britain paradise',
#  u'britain park',
#  u'britain perth',
#  u'britain phoenix',
#  u'britain pontlottyn',
#  u'britain premises',
#  u'britain public',
#  u'britain queen',
#  u'britain regatta',
#  u'britain regent',
#  u'britain residential',
#  u'britain retail',
#  u'britain riverside',
#  u'britain robertson',
#  u'britain rochdale',
#  u'britain ryhope',
#  u'britain sefton',
#  u'britain shirland',
#  u'britain sproughton',
#  u'britain st',
#  u'britain stanley',
#  u'britain station',
#  u'britain stockton',
#  u'britain sumatra',
#  u'britain swadlincote',
#  u'britain taplow',
#  u'britain thaxted',
#  u'britain the',
#  u'britain tower',
#  u'britain trencherfield',
#  u'britain tufton',
#  u'britain turpin',
#  u'britain upton',
#  u'britain vale',
#  u'britain warehouse',
#  u'britain warrington',
#  u'britain watling',
#  u'britain wellington',
#  u'britain west',
#  u'britain westerton',
#  u'britain westgate',
#  u'britain whiteshill',
#  u'britain wood',
#  u'britain woodhatch',
#  u'britain wrights',
#  u'britain york',
#  u'broad',
#  u'broad street',
#  u'broadway',
#  u'broadway ealing',
#  u'brook',
#  u'brook square',
#  u'brook street',
#  u'brookborough',
#  u'brookborough road',
#  u'brookfield',
#  u'brookfield apartments',
#  u'brookfield hall',
#  u'brookmount',
#  u'brookmount road',
#  u'brooks',
#  u'brooks lewes',
#  u'brookville',
#  u'brookville gardens',
#  u'broughton',
#  u'broughton road',
#  u'bru',
#  u'bru na',
#  u'bruachlan',
#  u'bruachlan westbury',
#  u'bruchlan',
#  u'bruchlan westbury',
#  u'brunswick',
#  u'brunswick street',
#  u'bryansford',
#  u'bryansford road',
#  u'bs23',
#  u'bs23 1qq',
#  u'bs26',
#  u'bs26 3ee',
#  u'bt30',
#  u'bt30 7sh',
#  u'bt32',
#  u'bt32 3gt',
#  u'bt35',
#  u'bt35 7nh',
#  u'bt51',
#  u'bt51 4pp',
#  u'bt52',
#  u'bt52 northern',
#  u'bt9',
#  u'bt9 5as',
#  u'btwshiells',
#  u'btwshiells ltd',
#  u'building',
#  u'building at',
#  u'building kavanaghfennell',
#  u'building mary',
#  u'building union',
#  u'bun',
#  u'bun caise',
#  u'burdett',
#  u'burdett road',
#  u'burgmuir',
#  u'burgmuir road',
#  u'burt',
#  u'burt donegal',
#  u'bury',
#  u'bury bl9',
#  u'business',
#  u'business campus',
#  u'business park',
#  u'buttery',
#  u'buttery court',
#  u'bweeng',
#  u'bweeng village',
#  u'by',
#  u'by sea',
#  u'byrne',
#  u'byrne lands',
#  u'bywater',
#  u'bywater court',
#  u'ca14',
#  u'ca14 5xt',
#  u'ca20',
#  u'ca20 1dh',
#  u'cafe',
#  u'cafe pavilions',
#  u'caher',
#  u'caher recess',
#  u'caherdaniel',
#  u'caherdaniel kerry',
#  u'caherdavin',
#  u'caherdavin limerick',
#  u'caise',
#  u'caise rahoon',
#  u'calderbridge',
#  u'calderbridge seascale',
#  u'cambric',
#  u'cambric court',
#  u'campus',
#  u'campus maynooth',
#  u'capel',
#  u'capel building',
#  u'capel street',
#  u'capella',
#  u'capella court',
#  u'capita',
#  u'capita symonds',
#  u'cappry',
#  u'cappry ballybofey',
#  u'car',
#  u'car park',
#  u'car parking',
#  u'car spaces',
#  u'cardiff',
#  u'cardiff lane',
#  u'carlow',
#  u'carlow carlow',
#  u'carlow ireland',
#  u'carmanhall',
#  u'carmanhall road',
#  u'carnamuggagh',
#  u'carnamuggagh letterkenny',
#  u'carpenderstown',
#  u'carpenderstown road',
#  u'carragh',
#  u'carragh granard',
#  u'carricklongfield',
#  u'carricklongfield aughnacloy',
#  u'carrickmacross',
#  u'carrickmacross monaghan',
#  u'carrickmines',
#  u'carrickmines dublin_18',
#  u'carrickmines green',
#  u'carrickmines lands',
#  u'carrickmines manor',
#  u'carrigart',
#  u'carrigart donegal',
#  u'carrigtwohill',
#  u'carrigtwohill cork',
#  u'carrownamaddy',
#  u'carrownamaddy burt',
#  u'carysfort',
#  u'carysfort avenue',
#  u'cashel',
#  u'cashel tipperary',
#  u'casltebar',
#  u'casltebar mayo',
#  u'castle',
#  u'castle street',
#  u'castlebar',
#  u'castlebar mayo',
#  u'castlecomer',
#  u'castlecomer kilkenny',
#  u'castleconnell',
#  u'castleconnell limerick',
#  u'castlecourt',
#  u'castlecourt broad',
#  u'castlefin',
#  u'castlefin donegal',
#  u'castleforbes',
#  u'castleforbes house',
#  u'castleforbes road',
#  u'castleforbes square',
#  u'castleknock',
#  u'castleknock dublin',
#  u'castleknock dublin_15',
#  u'castlemarket',
#  u'castlemarket south',
#  u'castlemartyr',
#  u'castlemartyr cork',
#  u'castlemartyr resort',
#  u'castlerock',
#  u'castlerock castleconnell',
#  u'castletownshend',
#  u'castletownshend cork',
#  u'castletroy',
#  u'castletroy limerick',
#  u'castlewoods',
#  u'castlewoods bandon',
#  u'cavan',
#  u'cavan ireland',
#  u'caveland',
#  u'caveland farm',
#  u'cecil',
#  u'cecil street',
#  u'cedar',
#  u'cedar downs',
#  u'cedars',
#  u'cedars ballybofey',
#  u'central',
#  u'central llp',
#  u'centre',
#  u'centre bangor',
#  u'centre btwshiells',
#  u'centre castleknock',
#  u'centre cobh',
#  u'centre croughwell',
#  u'centre longford',
#  u'centre maynooth',
#  u'centre oranmore',
#  u'centre raheen',
#  u'centre savills',
#  u'centre the',
#  u'centrepoint',
#  u'centrepoint business',
#  u'cerain',
#  u'cerain units',
#  u'certain',
#  u'certain assets',
#  u'certain blocks',
#  u'certain commercial',
#  u'certain houses',
#  u'certain property',
#  u'certain residential',
#  u'certain units',
#  u'certian',
#  u'certian units',
#  u'certrain',
#  u'certrain units',
#  u'ch41',
#  u'ch41 5ad',
#  u'ch42',
#  u'ch42 3uz',
#  u'ch49',
#  u'ch49 9bz',
#  u'chambers',
#  u'chambers peter',
#  u'chapel',
#  u'chapel lane',
#  u'chapel street',
#  u'chapelizod',
#  u'chapelizod dublin_20',
#  u'charlemont',
#  u'charlemont exchange',
#  u'charlemont griffith',
#  u'charlemont street',
#  u'charlotte',
#  u'charlotte quay',
#  u'chatham',
#  u'chatham court',
#  u'chatham house',
#  u'chatham row',
#  u'chatham street',
#  u'cheam',
#  u'cheam sutton',
#  u'chelmsford',
#  u'chelmsford essex',
#  u'cherryvalley',
#  u'cherryvalley rathmoylan',
#  u'cheshire',
#  u'cheshire great',
#  u'chesterfield',
#  u'chesterfield grove',
#  u'chesterfield s42',
#  u'chivers',
#  u'chivers coolock',
#  u'chlair',
#  u'chlair ennis',
#  u'chnoic',
#  u'chnoic dingle',
#  u'choiste',
#  u'choiste monksland',
#  u'chruch',
#  u'chruch road',
#  ...]

# %% [markdown]
# ## Dimensionality Reduction (SVD)
# Transforming the sparse matrix into a dense matrix representation
#
# Using Singular Value Decomposition (SVD) a method akin to Prinicipal Components Analysis to map the full space onto a reduced feature space

# %%
## Dimensionality reduction and re-normalization
lsa = TruncatedSVD(n_components=100)
Y = lsa.fit_transform(X)
Z = Normalizer(copy=False).fit_transform(Y)
Z.shape
Z[:10,:10]
# Out:
# array([[ 0.11924113,  0.05229281,  0.04988765,  0.04992347,  0.05315117,
#         -0.06744666,  0.01986205,  0.02245181, -0.02055181,  0.00926942],
#        [ 0.16821145,  0.09624601,  0.06254825,  0.08077274,  0.05309414,
#         -0.16508467, -0.1605197 , -0.19629013,  0.00215084, -0.26133915],
#        [ 0.24555109, -0.09655024, -0.05122702,  0.05435969,  0.03505463,
#         -0.12386782,  0.02732184,  0.01775655,  0.07974116,  0.08730571],
#        [ 0.09565709,  0.00625136,  0.06177271,  0.12583615,  0.05994277,
#         -0.06216073, -0.06205304, -0.22311798,  0.20382012,  0.188455  ],
#        [ 0.13104335,  0.05847087,  0.04459808,  0.11051134,  0.06054177,
#         -0.11211423, -0.08354696, -0.34425971,  0.28788786,  0.27153602],
#        [ 0.14342467,  0.03562178,  0.06973662,  0.07942194,  0.07180114,
#         -0.17866618, -0.05801237, -0.23897176,  0.2582289 ,  0.27397402],
#        [ 0.21541348, -0.03304798, -0.03597288,  0.08161472,  0.06032855,
#         -0.14191557, -0.02339274, -0.32608432,  0.29403239,  0.26847197],
#        [ 0.25400008, -0.02071069, -0.00338419,  0.09169723,  0.08969258,
#         -0.2327452 , -0.09317553, -0.40772155,  0.27572283,  0.17297662],
#        [ 0.09903241,  0.00950853,  0.06436844,  0.12884895,  0.07823295,
#         -0.08147298, -0.06894688, -0.27396158,  0.24294277,  0.23274903],
#        [ 0.13148612,  0.06271736,  0.05834562,  0.09441773,  0.11163898,
#         -0.16799266, -0.02817221, -0.316432  ,  0.27068803,  0.29499785]])

# %% [markdown]
# ## Initial Clustering (K-Means)
# Split up the dataset into more manageable chunks

# %%
## Find good number of clusters to use
inertia = {}

for i in range(1,21):
    km = MiniBatchKMeans(n_clusters=i,init='k-means++',n_init=10,random_state=0
                         ,init_size=1000,batch_size=1000,verbose=False)
    t0 = time()
    km.fit(Z)
    print("testing n= "+str(i)+", done %0.3fs" % (time() - t0))
    inertia[i] = km.inertia_   

#%% Choose best num clusters
min(inertia.iterkeys(), key=(lambda key: inertia[key]))    
        
# fig = plt.figure(1, figsize=(6, 6))
# plt.clf()
plt.scatter(inertia.keys(), inertia.values()
            ,c=[1.0-j for j in inertia.values()],cmap="YlGnBu"
            ,alpha=0.8,marker='o',linewidths=0.3)

f = interpolate.interp1d(inertia.keys(), inertia.values())
xnew = np.arange(min(inertia.keys()),max(inertia.keys()),0.1)
plt.plot(xnew,f(xnew),color="b",linestyle="--")
plt.show
# Out:
# testing n= 1, done 0.138s
# testing n= 2, done 0.140s
# testing n= 3, done 0.159s
# testing n= 4, done 0.171s
# testing n= 5, done 0.185s
# testing n= 6, done 0.206s
# testing n= 7, done 0.212s
# testing n= 8, done 0.211s
# testing n= 9, done 0.235s
# testing n= 10, done 0.250s
# testing n= 11, done 0.262s
# testing n= 12, done 0.270s
# testing n= 13, done 0.289s
# testing n= 14, done 0.287s
# testing n= 15, done 0.305s
# testing n= 16, done 0.315s
# testing n= 17, done 0.335s
# testing n= 18, done 0.351s
# testing n= 19, done 0.367s
# testing n= 20, done 0.369s
# <function matplotlib.pyplot.show>

# %%
## Run using fixed chosen cluster count
clust = 15
km = MiniBatchKMeans(n_clusters=clust,init='k-means++',n_init=10,random_state=0
                         ,init_size=1000,batch_size=1000,verbose=False)
km.fit(Z)

#%% Make quick observations of clusters
A = pd.DataFrame(Z)
A["label1"] = km.labels_
A["label1_color"] = (km.labels_+1)/(max(km.labels_)+1)
A.groupby("label1")[0].count()


## Quick plot
fig = plt.figure(1, figsize=(10, 10))
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
labels = A["label1"]
rndpts = np.sort(np.random.choice(A.shape[0], min(1000,A.shape[0]), replace=False))

ax.scatter(A.iloc[rndpts,0],A.iloc[rndpts,1],A.iloc[rndpts,2]
        ,c=A.iloc[rndpts].label1_color
        ,cmap="jet",alpha=0.8,marker='o',linewidths=0.1)

# plot centroids
cntrs = km.cluster_centers_[:,0:3]
ax.scatter(cntrs[:,0],cntrs[:,1],cntrs[:,2]
        ,c=np.arange(1,clust+1,1)/(clust+1)
        ,cmap="jet",alpha=1,marker='D',s=100, linewidths=1.5)

ax.set_xlabel('SVD 1st')
ax.set_ylabel('SVD 2nd')
ax.set_zlabel('SVD 3rd')
plt.show()

# %% [markdown]
# ## Extract clusters of companies for manual labelling

# %%
del df['human_suggested_id']
df['label'] = km.labels_
df.insert(0, 'human_suggested_id', "")

for i in np.unique(km.labels_):
    df.loc[df.label==i].to_csv('data/human_tagging/df_lbl_'+str(i)+'.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-b5fe9c786e47> in <module>()
# ----> 1 del df['human_suggested_id']
#       2 df['label'] = km.labels_
#       3 df.insert(0, 'human_suggested_id', "")
#       4
#       5 for i in np.unique(km.labels_):
#
# /Users/jon/anaconda/envs/textmining/lib/python2.7/site-packages/pandas/core/generic.pyc in __delitem__(self, key)
#    1137             # there was no match, this call should raise the appropriate
#    1138             # exception:
# -> 1139             self._data.delete(key)
#    1140
#    1141         try:
#
# /Users/jon/anaconda/envs/textmining/lib/python2.7/site-packages/pandas/core/internals.pyc in delete(self, item)
#    2944
#    2945         is_unique = self.items.is_unique
# -> 2946         loc = self.items.get_loc(item)
#    2947
#    2948         # dupe keys may return mask
#
# /Users/jon/anaconda/envs/textmining/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key)
#    1015         loc : int if unique index, possibly slice or mask if not
#    1016         """
# -> 1017         return self._engine.get_loc(_values_from_object(key))
#    1018
#    1019     def get_value(self, series, key):
#
# /Users/jon/anaconda/envs/textmining/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3620)()
#
# /Users/jon/anaconda/envs/textmining/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3498)()
#
# /Users/jon/anaconda/envs/textmining/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:11324)()
#
# /Users/jon/anaconda/envs/textmining/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:11277)()
#
# KeyError: 'human_suggested_id'

# %%
## Take a look at an example set
df.loc[df.label==0]
